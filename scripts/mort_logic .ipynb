# %%
mort = read.csv('/Data/common/mort_icu.csv')

# %%
test  <-  read.table('/Data/common/Ventilator_demo.tsv', header=T, sep='\t')

# %%
test
# Out:
#       icustay_id gender age      height subject_id hadm_id admission_type
# 1     294912     M       57.0272 178.00 72530      189421  EMERGENCY
# 2     262146     F       77.9385 157.48 14114      189388  ELECTIVE
# 3     229381     F       42.2699 165.10 47927      161682  EMERGENCY
# 4     294919     M       70.8541 172.72 86078      182281  EMERGENCY
# 5     262154     F      300.0023 157.00 94698      152925  EMERGENCY
# 6     229387     M       68.0426 170.18  6561      142014  EMERGENCY
# 7     294925     F      300.0013 135.00 91926      128362  EMERGENCY
# 8     229390     M       74.7386 180.00 71277      189952  EMERGENCY
# 9     262164     M       69.4624 175.00 46836      199740  EMERGENCY
# 10    294933     F       75.6388 162.56  7494      169113  ELECTIVE
# 11    229396     M       64.3319 183.00 88649      135549  EMERGENCY
# 12    294935     M       30.9255 182.88 29046      131576  ELECTIVE
# 13    262169     M       80.4316 182.88 22241      194800  EMERGENCY
# ...

# %% [markdown]
# # distime,
# admittime

# %%
icu_
# Out:
# Error in is.data.frame(x): object 'mort' not found
# Traceback:
#
# 1. colnames(mort)
# 2. is.data.frame(x)
